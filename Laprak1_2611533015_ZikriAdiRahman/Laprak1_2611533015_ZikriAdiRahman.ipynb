# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **PRAKTIKUM ALGORITMA DAN PEMROGRAMAN**
#
# **Pengenalan Python, VS Code, dan Koneksi ke GitHub**
#
# **Disusun Oleh :**
#
# **ZIKRI ADI RAHMAN**
#
# **2611533015**
#
# **Dosen Pengampu :**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum :**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h1 align="center">KATA PENGANTAR</h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pengenalan Python dan Pembuatan akun Github.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep Python dan Github pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 3 September 2026

# %% [markdown]
# ---
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Sebelum mempelajari konsep-konsep struktur data yang lebih kompleks, mahasiswa perlu terlebih dahulu memiliki fondasi dasar berupa lingkungan pengembangan (development environment) yang siap digunakan serta pemahaman dasar mengenai bahasa pemrograman yang akan dipakai selama praktikum, yaitu Python. Selain itu, penggunaan sistem kontrol versi seperti Git dan platform GitHub menjadi hal yang penting dalam dunia pemrograman modern, karena memungkinkan penyimpanan kode secara terstruktur, kolaborasi antar pengembang, serta dokumentasi progres belajar secara berkelanjutan. Oleh karena itu, praktikum pertama ini berfokus pada instalasi dan pengenalan alat bantu (tools) dasar berupa Visual Studio Code (VSCode) sebagai code editor, Python sebagai bahasa pemrograman, serta GitHub sebagai platform version control, sebelum masuk ke materi struktur data pada pertemuan-pertemuan berikutnya.
#
# ## 1.2 Tujuan
# 1. Mampu melakukan instalasi Visual Studio Code (VSCode) sebagai code editor untuk menulis    dan menjalankan program.
# 2. Mampu melakukan instalasi Python beserta pengaturan environment-nya agar dapat dijalankan melalui VSCode.
# 3. Mampu membuat dan melakukan registrasi akun GitHub sebagai platform version control dan kolaborasi.
# 4. Mampu menulis dan menjalankan program Python sederhana menggunakan fungsi print().
#
# ## 1.3 Manfaat
# 1. Mahasiswa memiliki lingkungan pengembangan (development environment) yang siap digunakan untuk praktikum selanjutnya.
# 2. Mahasiswa memahami dasar penggunaan Python sebagai bahasa pemrograman yang akan dipakai sepanjang praktikum Struktur Data.
# 3. Mahasiswa memiliki akun GitHub yang dapat digunakan untuk menyimpan dan mendokumentasikan kode program secara online.

# %% [markdown]
# ---
# <h1 align="center">BAB II<br>PEMBAHASAN</h1>
#
# ## 2.1 Dasar Teori
# 1. Visual Studio Code (VSCode) adalah code editor gratis dan open-source buatan Microsoft yang mendukung berbagai bahasa pemrograman melalui ekstensi (extension), termasuk Python. VSCode banyak digunakan karena ringan, fleksibel, dan memiliki fitur seperti debugging, terminal terintegrasi, serta dukungan Git bawaan.
# 2. Python adalah bahasa pemrograman tingkat tinggi (high-level) yang bersifat interpreted, dengan sintaks yang sederhana dan mudah dipahami, sehingga sering digunakan untuk pembelajaran pemrograman, pengolahan data, hingga pengembangan aplikasi.
# 3. Git adalah sistem version control yang digunakan untuk melacak perubahan pada kode program, sedangkan GitHub adalah platform berbasis web yang memungkinkan penyimpanan repository Git secara online serta kolaborasi antar pengguna.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
"""
halo ini cuman komentar biasa
"""
# ini komentar juga 

print("Hallo Dunia")
print()
print("Program Ini Menghasilkan")
print("Empat Baris Output")
print(r"/||//\\//\\\\")
print("Program ini " + "Dibuat Oleh Zikri" + "2611533015")
# Out:
# Hallo Dunia
#
# Program Ini Menghasilkan
# Empat Baris Output
# /||//\\//\\\\
# Program ini Dibuat Oleh Zikri 2611533015

# %% [markdown]
# **Penjelasan :**
# 1. Baris pertama menggunakan fungsi bawaan Python print() untuk menampilkan teks "Perkanalkan" ke layar, Untuk pendahuluan sebelum perkenalan.
# 2. Baris kedua, ketiga, dan keempat menampilkan identitas mahasiswa sebagai latihan tambahan penggunaan fungsi print() dengan string yang berbeda.
# 3. Program ini dijalankan menggunakan Bahasa Python.

# %% [markdown]
# ---
# <h1 align="center">BAB III<br>KESIMPULAN</h1>
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa instalasi dan pengenalan alat bantu dasar seperti Visual Studio Code, Python, dan GitHub merupakan langkah awal yang penting sebelum mempelajari materi struktur data yang lebih mendalam. Melalui praktikum ini, mahasiswa berhasil menyiapkan lingkungan pengembangan yang akan digunakan sepanjang mata kuliah, memahami dasar penulisan program Python melalui fungsi print(), serta memiliki akun GitHub yang dapat dimanfaatkan untuk menyimpan dan mendokumentasikan kode program secara daring.
#
# Dalam konteks pemrograman, kesiapan tools seperti code editor, bahasa pemrograman, dan version control ini akan mempermudah proses belajar pada praktikum-praktikum berikutnya, khususnya dalam mengimplementasikan berbagai struktur data menggunakan Python.

# %% [markdown]
# ---
# <h1 align="center">DAFTAR PUSTAKA</h1>
#
# [1] Microsoft, "Visual Studio Code Documentation," [Online]. Tersedia: https://code.visualstudio.com/docs [Diakses 2026].
#
# [2] Python Software Foundation, "The Python Tutorial," [Online]. Tersedia: https://docs.python.org/3/tutorial/ [Diakses 2026].
#
# [3] GitHub, Inc., "Getting Started with GitHub," [Online]. Tersedia: https://docs.github.com/en/get-started [Diakses 2026].
